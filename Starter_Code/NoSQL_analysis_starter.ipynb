# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Notebook Set Up

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint
import pandas as pd

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our database
db.list_collection_names()
# Out:
# ['establishments']

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 3: Exploratory Analysis
# Unless otherwise stated, for each question:
# * Use `count_documents` to display the number of documents contained in the result.
# * Display the first document in the results using `pprint`.
# * Convert the result to a Pandas DataFrame, print the number of rows in the DataFrame, and display the first 10 rows.

# %% [markdown]
# ### 1. Which establishments have a hygiene score equal to 20?

# %%
# Find the establishments with a hygiene score of 20
query = {'scores.Hygiene': {'$eq': 20}}

# Use count_documents to display the number of documents in the result
print("Number of results where establishment hygiene is equeal to 20: ", establishments.count_documents(query))

# Display the first document in the results using pprint
pprint(establishments.find_one(query))
# Out:
# Number of results where establishment hygiene is equeal to 20:  41
# {'AddressLine1': '5-6 Southfields Road',
#  'AddressLine2': 'Eastbourne',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'BusinessName': 'The Chase Rest Home',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4613.888288172291,
#  'FHRSID': 110681,
#  'LocalAuthorityBusinessID': '4029',
#  'LocalAuthorityCode': '102',
#  'LocalAuthorityEmailAddress': 'Customerfirst@eastbourne.gov.uk',
#  'LocalAuthorityName': 'Eastbourne',
#  'LocalAuthorityWebSite': 'http://www.eastbourne.gov.uk/foodratings',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'BN21 1BU',
#  'RatingDate': '2021-09-23T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': 0,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64f924ec57ccacbb83629928'),
#  'geocode': {'latitude': 50.769705, 'longitude': 0.27694},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/110681',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 20}}

# %%
# Convert the result to a Pandas DataFrame
hygiene_results = establishments.find(query)
hygiene_df = pd.DataFrame(list(hygiene_results))
hygiene_df.set_index('BusinessName', inplace=True)


# Display the number of rows in the DataFrame
print("The number of rows in our dataframe is: ", len(hygiene_df.index))

# Display the first 10 rows of the DataFrame
hygiene_df.head(10)
# Out:
# The number of rows in our dataframe is:  41
#                                                 _id   FHRSID
# BusinessName
# The Chase Rest Home        64f924ec57ccacbb83629928   110681  \
# Brenalwood                 64f924ec57ccacbb83629ca9   612039
# Melrose Hotel              64f924ec57ccacbb83629fb0   730933
# Seaford Pizza              64f924ec57ccacbb8362a19a   172735
# Golden Palace              64f924ec57ccacbb8362a1ac   172953
# Ashby's Butchers           64f924ec57ccacbb8362ab4f   512854
# South Sea Express Cuisine  64f924ec57ccacbb8362ad71  1537089
# Golden Palace              64f924ec57ccacbb8362c29e   155648
# The Tulip Tree             64f924ec57ccacbb8362c6dc  1012883
# F & S                      64f924ec57ccacbb8362cef1   644109
#
#                            ChangesByServerID LocalAuthorityBusinessID
# BusinessName
# The Chase Rest Home                        0                     4029  \
# Brenalwood                                 0                1970/FOOD
# Melrose Hotel                              0                1698/FOOD
# Seaford Pizza                              0             PI/000023858
# Golden Palace                              0             PI/000024532
# Ashby's Butchers                           0            12/00816/BUTH
# South Sea Express Cuisine                  0          22/00224/RESTUN
# Golden Palace                              0              EH/00006058
# The Tulip Tree                             0         17/00110/MIXED/S
# F & S                                      0                    41811
#
#                                                 BusinessType  BusinessTypeID
# BusinessName
# The Chase Rest Home                          Caring Premises               5  \
# Brenalwood                                   Caring Premises               5
# Melrose Hotel              Hotel/bed & breakfast/guest house            7842
# Seaford Pizza                         Takeaway/sandwich shop            7844
# Golden Palace                        Restaurant/Cafe/Canteen               1
# Ashby's Butchers                           Retailers - other            4613
# South Sea Express Cuisine            Restaurant/Cafe/Canteen               1
# Golden Palace                         Takeaway/sandwich shop            7844
# The Tulip Tree                       Restaurant/Cafe/Canteen               1
# F & S                                      Retailers - other            4613
#
#                                     AddressLine1        AddressLine2
# BusinessName
# The Chase Rest Home         5-6 Southfields Road          Eastbourne  \
# Brenalwood                             Hall Lane  Walton-on-the-Naze
# Melrose Hotel              53 Marine Parade East      Clacton On Sea
# Seaford Pizza                      4 High Street             Seaford
# Golden Palace                     5 South Street             Seaford
# Ashby's Butchers            777 Southchurch Road     Southend-On-Sea
# South Sea Express Cuisine    33 Alexandra Street     Southend-on-sea
# Golden Palace                      7 London Road            Rayleigh
# The Tulip Tree                     3 The Village       Chiddingstone
# F & S                                                 81 Southernhay
#
#                           AddressLine3 AddressLine4  ...
# BusinessName                                         ...
# The Chase Rest Home        East Sussex               ...  \
# Brenalwood                       Essex               ...
# Melrose Hotel                    Essex               ...
# Seaford Pizza              East Sussex               ...
# Golden Palace              East Sussex               ...
# Ashby's Butchers                 Essex               ...
# South Sea Express Cuisine        Essex               ...
# Golden Palace                    Essex               ...
# The Tulip Tree                    KENT               ...
# F & S                         Basildon        Essex  ...
#
#                                               LocalAuthorityWebSite
# BusinessName
# The Chase Rest Home        http://www.eastbourne.gov.uk/foodratings  \
# Brenalwood                            http://www.tendringdc.gov.uk/
# Melrose Hotel                         http://www.tendringdc.gov.uk/
# Seaford Pizza                   http://www.lewes-eastbourne.gov.uk/
# Golden Palace                   http://www.lewes-eastbourne.gov.uk/
# Ashby's Butchers                         http://www.southend.gov.uk
# South Sea Express Cuisine                http://www.southend.gov.uk
# Golden Palace                            http://www.rochford.gov.uk
# The Tulip Tree                         http://www.sevenoaks.gov.uk/
# F & S                                    http://www.basildon.gov.uk
#
#                                       LocalAuthorityEmailAddress
# BusinessName
# The Chase Rest Home              Customerfirst@eastbourne.gov.uk  \
# Brenalwood                            fhsadmin@tendringdc.gov.uk
# Melrose Hotel                         fhsadmin@tendringdc.gov.uk
# Seaford Pizza                ehealth.ldc@lewes-eastbourne.gov.uk
# Golden Palace                ehealth.ldc@lewes-eastbourne.gov.uk
# Ashby's Butchers             EnvironmentalHealth@southend.gov.uk
# South Sea Express Cuisine    EnvironmentalHealth@southend.gov.uk
# Golden Palace                   customerservices@rochford.gov.uk
# The Tulip Tree             environmental.health@sevenoaks.gov.uk
# F & S                                        ehs@basildon.gov.uk
#
#                                                                       scores
# BusinessName
# The Chase Rest Home        {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...  \
# Brenalwood                 {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...
# Melrose Hotel              {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...
# Seaford Pizza              {'Hygiene': 20, 'Structural': 10, 'ConfidenceI...
# Golden Palace              {'Hygiene': 20, 'Structural': 10, 'ConfidenceI...
# Ashby's Butchers           {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...
# South Sea Express Cuisine  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...
# Golden Palace              {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...
# The Tulip Tree             {'Hygiene': 20, 'Structural': 5, 'ConfidenceIn...
# F & S                      {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...
#
#                           SchemeType
# BusinessName
# The Chase Rest Home             FHRS  \
# Brenalwood                      FHRS
# Melrose Hotel                   FHRS
# Seaford Pizza                   FHRS
# Golden Palace                   FHRS
# Ashby's Butchers                FHRS
# South Sea Express Cuisine       FHRS
# Golden Palace                   FHRS
# The Tulip Tree                  FHRS
# F & S                           FHRS
#
#                                                                      geocode
# BusinessName
# The Chase Rest Home            {'longitude': 0.27694, 'latitude': 50.769705}  \
# Brenalwood                    {'longitude': 1.278721, 'latitude': 51.857536}
# Melrose Hotel                  {'longitude': 1.15927, 'latitude': 51.789429}
# Seaford Pizza                  {'longitude': 0.10202, 'latitude': 50.770885}
# Golden Palace                 {'longitude': 0.101446, 'latitude': 50.770724}
# Ashby's Butchers              {'longitude': 0.736349, 'latitude': 51.541448}
# South Sea Express Cuisine   {'longitude': 0.7121671, 'latitude': 51.5350065}
# Golden Palace                 {'longitude': 0.602364, 'latitude': 51.591515}
# The Tulip Tree             {'longitude': 0.146449998021126, 'latitude': 5...
# F & S                          {'longitude': 0.462307, 'latitude': 51.57005}
#
#                           RightToReply     Distance NewRatingPending
# BusinessName
# The Chase Rest Home                     4613.888288            False  \
# Brenalwood                              4617.965824            False
# Melrose Hotel                           4619.656144            False
# Seaford Pizza                           4620.421725            False
# Golden Palace                           4620.437179            False
# Ashby's Butchers                        4625.565258            False
# South Sea Express Cuisine               4626.200132            False
# Golden Palace                           4632.276890            False
# The Tulip Tree                          4633.934041            False
# F & S                                   4636.552523            False
#
#                                                                         meta
# BusinessName
# The Chase Rest Home        {'dataSource': None, 'extractDate': '0001-01-0...  \
# Brenalwood                 {'dataSource': None, 'extractDate': '0001-01-0...
# Melrose Hotel              {'dataSource': None, 'extractDate': '0001-01-0...
# Seaford Pizza              {'dataSource': None, 'extractDate': '0001-01-0...
# Golden Palace              {'dataSource': None, 'extractDate': '0001-01-0...
# Ashby's Butchers           {'dataSource': None, 'extractDate': '0001-01-0...
# South Sea Express Cuisine  {'dataSource': None, 'extractDate': '0001-01-0...
# Golden Palace              {'dataSource': None, 'extractDate': '0001-01-0...
# The Tulip Tree             {'dataSource': None, 'extractDate': '0001-01-0...
# F & S                      {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                                        links
# BusinessName
# The Chase Rest Home        [{'rel': 'self', 'href': 'https://api.ratings....
# Brenalwood                 [{'rel': 'self', 'href': 'https://api.ratings....
# Melrose Hotel              [{'rel': 'self', 'href': 'https://api.ratings....
# Seaford Pizza              [{'rel': 'self', 'href': 'https://api.ratings....
# Golden Palace              [{'rel': 'self', 'href': 'https://api.ratings....
# Ashby's Butchers           [{'rel': 'self', 'href': 'https://api.ratings....
# South Sea Express Cuisine  [{'rel': 'self', 'href': 'https://api.ratings....
# Golden Palace              [{'rel': 'self', 'href': 'http://api.ratings.f...
# The Tulip Tree             [{'rel': 'self', 'href': 'http://api.ratings.f...
# F & S                      [{'rel': 'self', 'href': 'http://api.ratings.f...
#
# [10 rows x 27 columns]

# %% [markdown]
# ### 2. Which establishments in London have a `RatingValue` greater than or equal to 4?

# %%
# Find the establishments with London as the Local Authority and has a RatingValue greater than or equal to 4.
query = {'LocalAuthorityName': {'$regex': 'London'},
    'RatingValue' : {'$gte': 4}}

# Use count_documents to display the number of documents in the result
print("Number of results where the establishment rating is 4 or higher: ", establishments.count_documents(query))

# Display the first document in the results using pprint
pprint(establishments.find_one(query))
# Out:
# Number of results where the establishment rating is 4 or higher:  33
# {'AddressLine1': 'Oak Apple Farm Building 103 Sheernes Docks',
#  'AddressLine2': 'Sheppy Kent',
#  'AddressLine3': '',
#  'AddressLine4': '',
#  'BusinessName': "Charlie's",
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4627.439467780196,
#  'FHRSID': 621707,
#  'LocalAuthorityBusinessID': 'PI/000025307',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'ME12',
#  'RatingDate': '2021-10-18T00:00:00',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingValue': 4,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64f924ec57ccacbb8362b341'),
#  'geocode': {'latitude': 51.369321, 'longitude': 0.508551},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/621707',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 10}}

# %%
# Convert the result to a Pandas DataFrame
rating_results = establishments.find(query)
rating_df = pd.DataFrame(rating_results)
rating_df.set_index('BusinessName', inplace=True)

# Display the number of rows in the DataFrame
print("Number of rows in our dataframe is : ", len(rating_df.index))

# Display the first 10 rows of the DataFrame
rating_df.head(10)
# Out:
# Number of rows in our dataframe is :  33
#                                                            _id   FHRSID
# BusinessName
# Charlie's                             64f924ec57ccacbb8362b341   621707  \
# Mv City Cruises Erasmus               64f924ec57ccacbb8362b669  1130836
# Benfleet Motor Yacht Club             64f924ec57ccacbb8362c1b6   293783
# Coombs Catering t/a The Lock and Key  64f924ec57ccacbb8362cfb5  1315095
# Tilbury Seafarers Centre              64f924ec57ccacbb8362cfb6   294474
# Mv Valulla                            64f924ec57ccacbb8362d6bf   294900
# Tereza Joanne                         64f924ed57ccacbb8362f7cd   293756
# Brick Lane Brews                      64f924ed57ccacbb8362fb93   878523
# The Nuance Group (UK) Limited         64f924ed57ccacbb8362fbae   293772
# WH Smith                              64f924ed57ccacbb8362fbaf   294606
#
#                                       ChangesByServerID
# BusinessName
# Charlie's                                             0  \
# Mv City Cruises Erasmus                               0
# Benfleet Motor Yacht Club                             0
# Coombs Catering t/a The Lock and Key                  0
# Tilbury Seafarers Centre                              0
# Mv Valulla                                            0
# Tereza Joanne                                         0
# Brick Lane Brews                                      0
# The Nuance Group (UK) Limited                         0
# WH Smith                                              0
#
#                                      LocalAuthorityBusinessID
# BusinessName
# Charlie's                                        PI/000025307  \
# Mv City Cruises Erasmus                          PI/000034075
# Benfleet Motor Yacht Club                        PI/000002614
# Coombs Catering t/a The Lock and Key             PI/000036464
# Tilbury Seafarers Centre                         PI/000014647
# Mv Valulla                                       PI/000019066
# Tereza Joanne                                    PI/000002538
# Brick Lane Brews                                 PI/000029844
# The Nuance Group (UK) Limited                    PI/000002585
# WH Smith                                         PI/000016185
#
#                                                  BusinessType  BusinessTypeID
# BusinessName
# Charlie's                             Other catering premises            7841  \
# Mv City Cruises Erasmus               Other catering premises            7841
# Benfleet Motor Yacht Club             Other catering premises            7841
# Coombs Catering t/a The Lock and Key  Restaurant/Cafe/Canteen               1
# Tilbury Seafarers Centre              Restaurant/Cafe/Canteen               1
# Mv Valulla                            Other catering premises            7841
# Tereza Joanne                         Other catering premises            7841
# Brick Lane Brews                      Restaurant/Cafe/Canteen               1
# The Nuance Group (UK) Limited               Retailers - other            4613
# WH Smith                                    Retailers - other            4613
#
#                                                                            AddressLine1
# BusinessName
# Charlie's                                    Oak Apple Farm Building 103 Sheernes Docks  \
# Mv City Cruises Erasmus                                              Cherry Garden Pier
# Benfleet Motor Yacht Club                                                    Ferry Road
# Coombs Catering t/a The Lock and Key                                  Leslie Ford House
# Tilbury Seafarers Centre                                      Tenants Row Tilbury Docks
# Mv Valulla                            Reeds River Cruises LtdKings ReachRiver Thames...
# Tereza Joanne                         Funcraft UK Ltd King George V Dock Woolwich Ma...
# Brick Lane Brews                                           Air side London City Airport
# The Nuance Group (UK) Limited                         Duty Free Shop Passenger Terminal
# WH Smith                                                            London City Airport
#
#                                                               AddressLine2
# BusinessName
# Charlie's                                                      Sheppy Kent  \
# Mv City Cruises Erasmus                   Cherry Garden Street Rotherhithe
# Benfleet Motor Yacht Club                             South Benfleet Essex
# Coombs Catering t/a The Lock and Key                               Tilbury
# Tilbury Seafarers Centre                                     Tilbury Essex
# Mv Valulla                                                          London
# Tereza Joanne                                                       London
# Brick Lane Brews                                                    London
# The Nuance Group (UK) Limited         London City AirportRoyal DocksLondon
# WH Smith                                                 Silvertown London
#
#                                      AddressLine3 AddressLine4  ...
# BusinessName                                                    ...
# Charlie's                                                       ...  \
# Mv City Cruises Erasmus                  Charlton               ...
# Benfleet Motor Yacht Club                                       ...
# Coombs Catering t/a The Lock and Key     Charlton               ...
# Tilbury Seafarers Centre                                        ...
# Mv Valulla                                                      ...
# Tereza Joanne                                                   ...
# Brick Lane Brews                                                ...
# The Nuance Group (UK) Limited                                   ...
# WH Smith                                                        ...
#
#                                                                   LocalAuthorityWebSite
# BusinessName
# Charlie's                             http://www.cityoflondon.gov.uk/Corporation/hom...  \
# Mv City Cruises Erasmus               http://www.cityoflondon.gov.uk/Corporation/hom...
# Benfleet Motor Yacht Club             http://www.cityoflondon.gov.uk/Corporation/hom...
# Coombs Catering t/a The Lock and Key  http://www.cityoflondon.gov.uk/Corporation/hom...
# Tilbury Seafarers Centre              http://www.cityoflondon.gov.uk/Corporation/hom...
# Mv Valulla                            http://www.cityoflondon.gov.uk/Corporation/hom...
# Tereza Joanne                         http://www.cityoflondon.gov.uk/Corporation/hom...
# Brick Lane Brews                      http://www.cityoflondon.gov.uk/Corporation/hom...
# The Nuance Group (UK) Limited         http://www.cityoflondon.gov.uk/Corporation/hom...
# WH Smith                              http://www.cityoflondon.gov.uk/Corporation/hom...
#
#                                                 LocalAuthorityEmailAddress
# BusinessName
# Charlie's                             publicprotection@cityoflondon.gov.uk  \
# Mv City Cruises Erasmus               publicprotection@cityoflondon.gov.uk
# Benfleet Motor Yacht Club             publicprotection@cityoflondon.gov.uk
# Coombs Catering t/a The Lock and Key  publicprotection@cityoflondon.gov.uk
# Tilbury Seafarers Centre              publicprotection@cityoflondon.gov.uk
# Mv Valulla                            publicprotection@cityoflondon.gov.uk
# Tereza Joanne                         publicprotection@cityoflondon.gov.uk
# Brick Lane Brews                      publicprotection@cityoflondon.gov.uk
# The Nuance Group (UK) Limited         publicprotection@cityoflondon.gov.uk
# WH Smith                              publicprotection@cityoflondon.gov.uk
#
#                                                                                  scores
# BusinessName
# Charlie's                             {'Hygiene': 5, 'Structural': 10, 'ConfidenceIn...  \
# Mv City Cruises Erasmus               {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...
# Benfleet Motor Yacht Club             {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...
# Coombs Catering t/a The Lock and Key  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...
# Tilbury Seafarers Centre              {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...
# Mv Valulla                            {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...
# Tereza Joanne                         {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...
# Brick Lane Brews                      {'Hygiene': 10, 'Structural': 5, 'ConfidenceIn...
# The Nuance Group (UK) Limited         {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...
# WH Smith                              {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...
#
#                                      SchemeType
# BusinessName
# Charlie's                                  FHRS  \
# Mv City Cruises Erasmus                    FHRS
# Benfleet Motor Yacht Club                  FHRS
# Coombs Catering t/a The Lock and Key       FHRS
# Tilbury Seafarers Centre                   FHRS
# Mv Valulla                                 FHRS
# Tereza Joanne                              FHRS
# Brick Lane Brews                           FHRS
# The Nuance Group (UK) Limited              FHRS
# WH Smith                                   FHRS
#
#                                                                                 geocode
# BusinessName
# Charlie's                                {'longitude': 0.508551, 'latitude': 51.369321}  \
# Mv City Cruises Erasmus               {'longitude': 0.249255999922752, 'latitude': 5...
# Benfleet Motor Yacht Club                {'longitude': 0.561954, 'latitude': 51.543831}
# Coombs Catering t/a The Lock and Key  {'longitude': 0.346336990594864, 'latitude': 5...
# Tilbury Seafarers Centre                 {'longitude': 0.346325, 'latitude': 51.464078}
# Mv Valulla                               {'longitude': 0.287555, 'latitude': 51.504071}
# Tereza Joanne                            {'longitude': 0.069286, 'latitude': 51.501121}
# Brick Lane Brews                         {'longitude': 0.048006, 'latitude': 51.503733}
# The Nuance Group (UK) Limited            {'longitude': 0.047966, 'latitude': 51.504112}
# WH Smith                              {'longitude': 0.0479655750095844, 'latitude': ...
#
#                                      RightToReply     Distance
# BusinessName
# Charlie's                                          4627.439468  \
# Mv City Cruises Erasmus                            4627.873179
# Benfleet Motor Yacht Club                          4631.968418
# Coombs Catering t/a The Lock and Key               4636.846754
# Tilbury Seafarers Centre                           4636.847650
# Mv Valulla                                         4640.460834
# Tereza Joanne                                      4648.301822
# Brick Lane Brews                                   4649.173485
# The Nuance Group (UK) Limited                      4649.188826
# WH Smith                                           4649.188850
#
#                                      NewRatingPending
# BusinessName
# Charlie's                                       False  \
# Mv City Cruises Erasmus                         False
# Benfleet Motor Yacht Club                       False
# Coombs Catering t/a The Lock and Key            False
# Tilbury Seafarers Centre                        False
# Mv Valulla                                      False
# Tereza Joanne                                   False
# Brick Lane Brews                                False
# The Nuance Group (UK) Limited                   False
# WH Smith                                        False
#
#                                                                                    meta
# BusinessName
# Charlie's                             {'dataSource': None, 'extractDate': '0001-01-0...  \
# Mv City Cruises Erasmus               {'dataSource': None, 'extractDate': '0001-01-0...
# Benfleet Motor Yacht Club             {'dataSource': None, 'extractDate': '0001-01-0...
# Coombs Catering t/a The Lock and Key  {'dataSource': None, 'extractDate': '0001-01-0...
# Tilbury Seafarers Centre              {'dataSource': None, 'extractDate': '0001-01-0...
# Mv Valulla                            {'dataSource': None, 'extractDate': '0001-01-0...
# Tereza Joanne                         {'dataSource': None, 'extractDate': '0001-01-0...
# Brick Lane Brews                      {'dataSource': None, 'extractDate': '0001-01-0...
# The Nuance Group (UK) Limited         {'dataSource': None, 'extractDate': '0001-01-0...
# WH Smith                              {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                                                   links
# BusinessName
# Charlie's                             [{'rel': 'self', 'href': 'https://api.ratings....
# Mv City Cruises Erasmus               [{'rel': 'self', 'href': 'http://api.ratings.f...
# Benfleet Motor Yacht Club             [{'rel': 'self', 'href': 'http://api.ratings.f...
# Coombs Catering t/a The Lock and Key  [{'rel': 'self', 'href': 'http://api.ratings.f...
# Tilbury Seafarers Centre              [{'rel': 'self', 'href': 'http://api.ratings.f...
# Mv Valulla                            [{'rel': 'self', 'href': 'http://api.ratings.f...
# Tereza Joanne                         [{'rel': 'self', 'href': 'http://api.ratings.f...
# Brick Lane Brews                      [{'rel': 'self', 'href': 'http://api.ratings.f...
# The Nuance Group (UK) Limited         [{'rel': 'self', 'href': 'http://api.ratings.f...
# WH Smith                              [{'rel': 'self', 'href': 'http://api.ratings.f...
#
# [10 rows x 27 columns]

# %% [markdown]
# ### 3. What are the top 5 establishments with a `RatingValue` rating value of 5, sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?

# %%
# Search within 0.01 degree on either side of the latitude and longitude.
# Rating value must equal 5
# Sort by hygiene score

degree_search = 0.01
latitude = establishments.find({"BusinessName": "Penang Flavours"})[0]['geocode']['latitude']
longitude = establishments.find({"BusinessName": "Penang Flavours"})[0]['geocode']['longitude']

query = {'RatingValue': 5, 
         'geocode.latitude': {'$lte': (latitude + degree_search), '$gte': (latitude - degree_search)}, 
         'geocode.longitude': {'$lte': (longitude + degree_search), '$gte': (longitude - degree_search)} 
         }

sort =  [('scores.Hygiene', 1)]

# Print the results
q3_results = establishments.find(query).sort(sort).limit(5)
for establishment in q3_results:
    pprint(establishment)
# Out:
# {'AddressLine1': '130 - 132 Plumstead High Street',
#  'AddressLine2': '',
#  'AddressLine3': 'Plumstead',
#  'AddressLine4': 'Greenwich',
#  'BusinessName': 'Volunteer',
#  'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  'ChangesByServerID': 0,
#  'Distance': 4646.965634598608,
#  'FHRSID': 694609,
#  'LocalAuthorityBusinessID': 'PI/000116619',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'SE18 1JQ',
#  'RatingDate': '2019-08-05T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64f924ed57ccacbb8362f188'),
#  'geocode': {'latitude': 51.4873437, 'longitude': 0.09208},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/694609',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}
# {'AddressLine1': '35 Lakedale Road',
#  'AddressLine2': '',
#  'AddressLine3': 'Plumstead',
#  'AddressLine4': 'Greenwich',
#  'BusinessName': 'Atlantic Fish Bar',
#  'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  'ChangesByServerID': 0,
#  'Distance': 4646.974611855838,
#  'FHRSID': 694478,
#  'LocalAuthorityBusinessID': 'PI/000086506',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'SE18 1PR',
#  'RatingDate': '2021-06-16T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64f924ed57ccacbb8362f19f'),
#  'geocode': {'latitude': 51.4867296, 'longitude': 0.0912164},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/694478',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 0}}
# {'AddressLine1': '17 Lakedale Road',
#  'AddressLine2': '',
#  'AddressLine3': 'Plumstead',
#  'AddressLine4': 'Greenwich',
#  'BusinessName': 'Lumbini Grocery Ltd T/A Al-Iman',
#  'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  'ChangesByServerID': 0,
#  'Distance': 4646.975587048333,
#  'FHRSID': 909912,
#  'LocalAuthorityBusinessID': 'PI/000201100',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'SE18 1PP',
#  'RatingDate': '2020-10-20T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64f924ed57ccacbb8362f1a1'),
#  'geocode': {'latitude': 51.4871632, 'longitude': 0.0916256},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/909912',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 5}}
# {'AddressLine1': '144 - 146 Plumstead High Street',
#  'AddressLine2': '',
#  'AddressLine3': 'Plumstead',
#  'AddressLine4': 'Greenwich',
#  'BusinessName': 'Iceland',
#  'BusinessType': 'Retailers - supermarkets/hypermarkets',
#  'BusinessTypeID': 7840,
#  'ChangesByServerID': 0,
#  'Distance': 4646.946071297699,
#  'FHRSID': 695223,
#  'LocalAuthorityBusinessID': 'PI/000178842',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'SE18 1JQ',
#  'RatingDate': '2019-11-13T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64f924ed57ccacbb8362f15a'),
#  'geocode': {'latitude': 51.4871482849121, 'longitude': 0.0924199968576431},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/695223',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 5}}
# {'AddressLine1': 'Restaurant And Premises 107A Plumstead High Street',
#  'AddressLine2': '',
#  'AddressLine3': 'Plumstead',
#  'AddressLine4': 'Greenwich',
#  'BusinessName': 'Howe and Co Fish and Chips - Van 17',
#  'BusinessType': 'Mobile caterer',
#  'BusinessTypeID': 7846,
#  'ChangesByServerID': 0,
#  'Distance': 4646.95593107927,
#  'FHRSID': 1380578,
#  'LocalAuthorityBusinessID': '14425',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'SE18 1SE',
#  'RatingDate': '2021-11-11T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64f924ed57ccacbb8362f168'),
#  'geocode': {'latitude': 51.4875335693359, 'longitude': 0.0925370007753372},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1380578',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}

# %%
# Convert result to Pandas DataFrame

q3_results = establishments.find(query).sort(sort).limit(5)
q3_df = pd.DataFrame(q3_results)
q3_df.set_index('BusinessName', inplace=True)
q3_df
# Out:
#                                                           _id   FHRSID
# BusinessName
# Volunteer                            64f924ed57ccacbb8362f188   694609  \
# Atlantic Fish Bar                    64f924ed57ccacbb8362f19f   694478
# Lumbini Grocery Ltd T/A Al-Iman      64f924ed57ccacbb8362f1a1   909912
# Iceland                              64f924ed57ccacbb8362f15a   695223
# Howe and Co Fish and Chips - Van 17  64f924ed57ccacbb8362f168  1380578
#
#                                      ChangesByServerID
# BusinessName
# Volunteer                                            0  \
# Atlantic Fish Bar                                    0
# Lumbini Grocery Ltd T/A Al-Iman                      0
# Iceland                                              0
# Howe and Co Fish and Chips - Van 17                  0
#
#                                     LocalAuthorityBusinessID
# BusinessName
# Volunteer                                       PI/000116619  \
# Atlantic Fish Bar                               PI/000086506
# Lumbini Grocery Ltd T/A Al-Iman                 PI/000201100
# Iceland                                         PI/000178842
# Howe and Co Fish and Chips - Van 17                    14425
#
#                                                               BusinessType
# BusinessName
# Volunteer                                                Pub/bar/nightclub  \
# Atlantic Fish Bar                                   Takeaway/sandwich shop
# Lumbini Grocery Ltd T/A Al-Iman                          Retailers - other
# Iceland                              Retailers - supermarkets/hypermarkets
# Howe and Co Fish and Chips - Van 17                         Mobile caterer
#
#                                      BusinessTypeID
# BusinessName
# Volunteer                                      7843  \
# Atlantic Fish Bar                              7844
# Lumbini Grocery Ltd T/A Al-Iman                4613
# Iceland                                        7840
# Howe and Co Fish and Chips - Van 17            7846
#
#                                                                           AddressLine1
# BusinessName
# Volunteer                                              130 - 132 Plumstead High Street  \
# Atlantic Fish Bar                                                     35 Lakedale Road
# Lumbini Grocery Ltd T/A Al-Iman                                       17 Lakedale Road
# Iceland                                                144 - 146 Plumstead High Street
# Howe and Co Fish and Chips - Van 17  Restaurant And Premises 107A Plumstead High St...
#
#                                     AddressLine2 AddressLine3 AddressLine4
# BusinessName
# Volunteer                                           Plumstead    Greenwich  \
# Atlantic Fish Bar                                   Plumstead    Greenwich
# Lumbini Grocery Ltd T/A Al-Iman                     Plumstead    Greenwich
# Iceland                                             Plumstead    Greenwich
# Howe and Co Fish and Chips - Van 17                 Plumstead    Greenwich
#
#                                      ...             LocalAuthorityWebSite
# BusinessName                         ...
# Volunteer                            ...  http://www.royalgreenwich.gov.uk  \
# Atlantic Fish Bar                    ...  http://www.royalgreenwich.gov.uk
# Lumbini Grocery Ltd T/A Al-Iman      ...  http://www.royalgreenwich.gov.uk
# Iceland                              ...  http://www.royalgreenwich.gov.uk
# Howe and Co Fish and Chips - Van 17  ...  http://www.royalgreenwich.gov.uk
#
#                                        LocalAuthorityEmailAddress
# BusinessName
# Volunteer                            health@royalgreenwich.gov.uk  \
# Atlantic Fish Bar                    health@royalgreenwich.gov.uk
# Lumbini Grocery Ltd T/A Al-Iman      health@royalgreenwich.gov.uk
# Iceland                              health@royalgreenwich.gov.uk
# Howe and Co Fish and Chips - Van 17  health@royalgreenwich.gov.uk
#
#                                                                                 scores
# BusinessName
# Volunteer                            {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...  \
# Atlantic Fish Bar                    {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...
# Lumbini Grocery Ltd T/A Al-Iman      {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...
# Iceland                              {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...
# Howe and Co Fish and Chips - Van 17  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...
#
#                                     SchemeType
# BusinessName
# Volunteer                                 FHRS  \
# Atlantic Fish Bar                         FHRS
# Lumbini Grocery Ltd T/A Al-Iman           FHRS
# Iceland                                   FHRS
# Howe and Co Fish and Chips - Van 17       FHRS
#
#                                                                                geocode
# BusinessName
# Volunteer                               {'longitude': 0.09208, 'latitude': 51.4873437}  \
# Atlantic Fish Bar                     {'longitude': 0.0912164, 'latitude': 51.4867296}
# Lumbini Grocery Ltd T/A Al-Iman       {'longitude': 0.0916256, 'latitude': 51.4871632}
# Iceland                              {'longitude': 0.0924199968576431, 'latitude': ...
# Howe and Co Fish and Chips - Van 17  {'longitude': 0.0925370007753372, 'latitude': ...
#
#                                     RightToReply     Distance
# BusinessName
# Volunteer                                         4646.965635  \
# Atlantic Fish Bar                                 4646.974612
# Lumbini Grocery Ltd T/A Al-Iman                   4646.975587
# Iceland                                           4646.946071
# Howe and Co Fish and Chips - Van 17               4646.955931
#
#                                     NewRatingPending
# BusinessName
# Volunteer                                      False  \
# Atlantic Fish Bar                              False
# Lumbini Grocery Ltd T/A Al-Iman                False
# Iceland                                        False
# Howe and Co Fish and Chips - Van 17            False
#
#                                                                                   meta
# BusinessName
# Volunteer                            {'dataSource': None, 'extractDate': '0001-01-0...  \
# Atlantic Fish Bar                    {'dataSource': None, 'extractDate': '0001-01-0...
# Lumbini Grocery Ltd T/A Al-Iman      {'dataSource': None, 'extractDate': '0001-01-0...
# Iceland                              {'dataSource': None, 'extractDate': '0001-01-0...
# Howe and Co Fish and Chips - Van 17  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                                                  links
# BusinessName
# Volunteer                            [{'rel': 'self', 'href': 'http://api.ratings.f...
# Atlantic Fish Bar                    [{'rel': 'self', 'href': 'http://api.ratings.f...
# Lumbini Grocery Ltd T/A Al-Iman      [{'rel': 'self', 'href': 'http://api.ratings.f...
# Iceland                              [{'rel': 'self', 'href': 'http://api.ratings.f...
# Howe and Co Fish and Chips - Van 17  [{'rel': 'self', 'href': 'http://api.ratings.f...
#
# [5 rows x 27 columns]

# %% [markdown]
# ### 4. How many establishments in each Local Authority area have a hygiene score of 0?

# %%
# Create a pipeline that: 
# 1. Matches establishments with a hygiene score of 0
# 2. Groups the matches by Local Authority
# 3. Sorts the matches from highest to lowest
match_query = {'$match': {'scores.Hygiene': 0}}
group_query = {'$group': {'_id': "$LocalAuthorityName", 'establishment_count':{'$sum': 1}}}
sort_values = {'$sort': {'establishment_count': -1}}
pipeline = [match_query, group_query, sort_values]

# Print the number of documents in the result
results = list(establishments.aggregate(pipeline))
print("The number of results in our query is : ", len(results))

# Print the first 10 results
pprint(results[0:10])
# Out:
# The number of results in our query is :  55
# [{'_id': 'Thanet', 'establishment_count': 1130},
#  {'_id': 'Greenwich', 'establishment_count': 882},
#  {'_id': 'Maidstone', 'establishment_count': 713},
#  {'_id': 'Newham', 'establishment_count': 711},
#  {'_id': 'Swale', 'establishment_count': 686},
#  {'_id': 'Chelmsford', 'establishment_count': 680},
#  {'_id': 'Medway', 'establishment_count': 672},
#  {'_id': 'Bexley', 'establishment_count': 607},
#  {'_id': 'Southend-On-Sea', 'establishment_count': 586},
#  {'_id': 'Tendring', 'establishment_count': 542}]

# %%
# Convert the result to a Pandas DataFrame
q4_df = pd.DataFrame(results)


# Display the number of rows in the DataFrame
print("The number of rows in our dataframe is: ", len(q4_df.index))

# Display the first 10 rows of the DataFrame
q4_df.head(10)
# Out:
# The number of rows in our dataframe is:  55
#                _id  establishment_count
# 0           Thanet                 1130
# 1        Greenwich                  882
# 2        Maidstone                  713
# 3           Newham                  711
# 4            Swale                  686
# 5       Chelmsford                  680
# 6           Medway                  672
# 7           Bexley                  607
# 8  Southend-On-Sea                  586
# 9         Tendring                  542
